# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
locations = pd.read_csv('locations.csv')
locations
# Out:
#                   Station Display Name             Zone Customer Category  \
# 0              120 ENTRANCE / ACH MAIN     120 ENTRANCE       Hospitality
# 1            7700 PARMER / 7700 PARMER      7700 PARMER         Workplace
# 2               AISD PAC / AISD PAC #1         AISD PAC         Education
# 3               AISD PAC / AISD PAC #2         AISD PAC         Education
# 4               AISD PAC / AISD PAC #3         AISD PAC         Education
# 5               AISD PAC / AISD PAC #4         AISD PAC         Education
# 6               AISD PAC / AISD PAC #5         AISD PAC         Education
# 7        AMD GO GREEN / P100 FL4 OUTER     AMD GO GREEN         Workplace
# 8          AMD GO GREEN / P100 FLOOR 5     AMD GO GREEN         Workplace
# 9           ARBORETUM / N CAPITAL TX 1        ARBORETUM            Retail
# 10                    AUSTIN / 400 - 1           AUSTIN         Workplace
# 11                    AUSTIN / 400 - 2           AUSTIN         Workplace
# 12                    AUSTIN / 400 - 3           AUSTIN         Workplace
# 13               AUSTIN / AUSTIN 200 1           AUSTIN         Workplace
# 14               AUSTIN / AUSTIN 200 2           AUSTIN         Workplace
# 15               AUSTIN / AUSTIN 200 3           AUSTIN         Workplace
# 16            AVIATION / DOA - CONRAC1         AVIATION           Parking
# 17            AVIATION / DOA - CONRAC2         AVIATION           Parking
# 18                 AVIATION / LOT J NW         AVIATION         Municipal
# 19                 AVIATION / LOT J SW         AVIATION         Municipal
# 20       AXO GROUP LLC / AUSTIN CHARGE    AXO GROUP LLC         Workplace
# 21                B-AUSTIN / STATION 1         B-AUSTIN       Multifamily
# 22      BRANDYWINE AUST / CAPITAL ST 1  BRANDYWINE AUST         Workplace
# 23      BRANDYWINE AUST / CAPITAL ST 2  BRANDYWINE AUST         Workplace
# 24     BRANDYWINE AUST / ENCINO GARAGE  BRANDYWINE AUST         Workplace
# 25    BRANDYWINE AUST / GARAGE P1-L2-G  BRANDYWINE AUST         Workplace
# 26   BRANDYWINE AUST / GARAGE P2-L2-GW  BRANDYWINE AUST         Workplace
# 27     BRANDYWINE AUST / SOUTHWEST ST1  BRANDYWINE AUST         Workplace
# 28     BRANDYWINE AUST / SOUTHWEST ST2  BRANDYWINE AUST         Workplace
# 29             CATHERINE / CATHERINE 1        CATHERINE       Multifamily
# ..                                 ...              ...               ...
# 285        ROSCOE PROPERTI / TRIO MAIN  ROSCOE PROPERTI       Multifamily
# 286      ROSCOE PROPERTI / VOLUME MAIN  ROSCOE PROPERTI       Multifamily
# 287              RPP GARAGE / GARAGE 2       RPP GARAGE         Workplace
# 288             RPP GARAGE / GARAGE GW       RPP GARAGE         Workplace
# 289              RPP GARAGE / ISLAND 2       RPP GARAGE         Workplace
# 290             RPP GARAGE / ISLAND GW       RPP GARAGE         Workplace
# 291            SLEEP INN / SLEEP INN 1        SLEEP INN       Hospitality
# 292         SOLARWINDS / SOLARWINDS #1       SOLARWINDS         Workplace
# 293         SOLARWINDS / SOLARWINDS #2       SOLARWINDS         Workplace
# 294          SPRINGS AT TR / CLUBHOUSE    SPRINGS AT TR       Multifamily
# 295                     STATION 1 / #1        STATION 1         Workplace
# 296         STATION 1 / @ THE DISTRICT        STATION 1       Multifamily
# 297                STATION 1 / PLAZA 1        STATION 1         Workplace
# 298       STATION1-PP / PELOTON GARAGE      STATION1-PP         Workplace
# 299      STEINER RANCH / EV CHARGER #1    STEINER RANCH       Multifamily
# 300  SUSTAINABLEFOOD / SUSTAINABLEFOOD  SUSTAINABLEFOOD         Workplace
# 301         THE GROVE / MAIN STATION 1        THE GROVE       Multifamily
# 302    THE MEDVE GROUP / ARTS S AUSTIN  THE MEDVE GROUP       Multifamily
# 303     THE MEDVE GROUP / BARTON HILLS  THE MEDVE GROUP       Multifamily
# 304     THE MEDVE GROUP / TURTLE CREEK  THE MEDVE GROUP       Multifamily
# 305      THE PRESERVE / MAIN GATEWAY 1     THE PRESERVE       Multifamily
# 306    TIG REAL ESTATE / PIE-STATION 1  TIG REAL ESTATE         Workplace
# 307                            W1 / W1               W1         Workplace
# 308       WALLERCREEKSIDE / CREEKSIDE1  WALLERCREEKSIDE       Multifamily
# 309       WHITLEY MAIN / PIE-M WHITLEY     WHITLEY MAIN       Multifamily
# 310        WORKPLACE / PIE-P SUST FOOD        WORKPLACE         Workplace
# 311            YETI RAMBLERS / EVSE #1    YETI RAMBLERS         Workplace
# 312            YETI RAMBLERS / EVSE #2    YETI RAMBLERS         Workplace
# 313            YETI RAMBLERS / EVSE #3    YETI RAMBLERS         Workplace
# 314              YETI RAMBLERS / EVSE4    YETI RAMBLERS         Workplace
#
#      Postal Code EVSE Latitude and Longitude       Long        Lat
# 0          78704     (30.235856, -97.741577) -97.741577  30.235856
# 1          78729     (30.460477, -97.750024) -97.750024  30.460477
# 2          78723     (30.305454, -97.702666) -97.702666  30.305454
# 3          78723      (30.30538, -97.702537) -97.702537  30.305380
# 4          78723     (30.305343, -97.702408) -97.702408  30.305343
# 5          78723     (30.305269, -97.702269) -97.702269  30.305269
# 6          78723     (30.305204, -97.702108) -97.702108  30.305204
# 7          78735     (30.251635, -97.863914) -97.863914  30.251635
# 8          78735     (30.251499, -97.863984) -97.863984  30.251499
# 9          78759      (30.390246, -97.74825) -97.748250  30.390246
# 10         78701     (30.265028, -97.748448) -97.748448  30.265028
# 11         78701      (30.265052, -97.74844) -97.748440  30.265052
# 12         78701       (30.26505, -97.74849) -97.748490  30.265050
# 13         78701     (30.264423, -97.746071) -97.746071  30.264423
# 14         78701      (30.26445, -97.746142) -97.746142  30.264450
# 15         78701     (30.264505, -97.746067) -97.746067  30.264505
# 16         78719     (30.204711, -97.666322) -97.666322  30.204711
# 17         78719     (30.204655, -97.666451) -97.666451  30.204655
# 18         78719     (30.207439, -97.661026) -97.661026  30.207439
# 19         78719     (30.207559, -97.661039) -97.661039  30.207559
# 20         78702     (30.266047, -97.733139) -97.733139  30.266047
# 21         78745     (30.206406, -97.807047) -97.807047  30.206406
# 22         78746     (30.280123, -97.824008) -97.824008  30.280123
# 23         78746     (30.280357, -97.824244) -97.824244  30.280357
# 24         78735     (30.243787, -97.843763) -97.843763  30.243787
# 25         78746     (30.244181, -97.806692) -97.806692  30.244181
# 26         78735        (30.24609, -97.8046) -97.804600  30.246090
# 27         78735     (30.244005, -97.845965) -97.845965  30.244005
# 28         78735     (30.243945, -97.845952) -97.845952  30.243945
# 29         78704     (30.259096, -97.747775) -97.747775  30.259096
# ..           ...                         ...        ...        ...
# 285        78741     (30.228786, -97.726326) -97.726326  30.228786
# 286        78722      (30.28544, -97.715107) -97.715107  30.285440
# 287        78727     (30.429442, -97.755212) -97.755212  30.429442
# 288        78727     (30.429363, -97.755248) -97.755248  30.429363
# 289        78759     (30.427967, -97.754411) -97.754411  30.427967
# 290        78759     (30.428017, -97.754379) -97.754379  30.428017
# 291        78754     (30.329889, -97.661712) -97.661712  30.329889
# 292        78735      (30.251073, -97.86319) -97.863190  30.251073
# 293        78735     (30.250799, -97.862755) -97.862755  30.250799
# 294        78753     (30.394787, -97.653242) -97.653242  30.394787
# 295        78746     (30.304182, -97.828161) -97.828161  30.304182
# 296        78741      (30.22894, -97.719683) -97.719683  30.228940
# 297        78746     (30.347873, -97.800826) -97.800826  30.347873
# 298        78731     (30.386783, -97.768747) -97.768747  30.386783
# 299        78732     (30.383357, -97.873053) -97.873053  30.383357
# 300        78702     (30.278611, -97.710364) -97.710364  30.278611
# 301        78704     (30.236473, -97.782607) -97.782607  30.236473
# 302        78745     (30.221064, -97.770408) -97.770408  30.221064
# 303        78704     (30.261911, -97.773946) -97.773946  30.261911
# 304        78745     (30.204478, -97.783736) -97.783736  30.204478
# 305        78735     (30.246834, -97.846018) -97.846018  30.246834
# 306        78746     (30.265768, -97.779681) -97.779681  30.265768
# 307        78731     (30.314723, -97.756396) -97.756396  30.314723
# 308        78751     (30.315229, -97.724395) -97.724395  30.315229
# 309        78701     (30.265199, -97.742194) -97.742194  30.265199
# 310        78702     (30.278064, -97.710187) -97.710187  30.278064
# 311        78735     (30.256412, -97.871799) -97.871799  30.256412
# 312        78735     (30.255806, -97.872517) -97.872517  30.255806
# 313        78735      (30.25183, -97.876086) -97.876086  30.251830
# 314        78735     (30.251792, -97.876256) -97.876256  30.251792
#
# [315 rows x 7 columns]

# %%
plt.scatter(locations.Lat, locations.Long)

# %%
centroid = (np.sum(locations.Lat) / len(locations.Lat), np.sum(locations.Long) / len(locations.Long))

lat_normalized = []
for i in locations.Lat:
    lat_normalized.append(locations.Lat - centroid[0])

long_normalized = []
for i in locations.Long:
    long_normalized.append(locations.Long - centroid[1])

# %%
plt.scatter(lat_normalized, long_normalized)

# %%
cov = np.cov(lat_normalized, long_normalized)
cov[0][0]
cov[0][315]
# Out:
# 0.0007960116268289178

# %%
np.random.multivariate_normal(centroid, [[cov[0][0], cov[0][315]],[cov[1][0], cov[1][315]]])
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: covariance is not positive-semidefinite.
#   """Entry point for launching an IPython kernel.
# array([ 30.39614409, -97.73009898])

# %%
# set this to however many values you want
out = []
for i in range(0,100):
    out.append(np.random.multivariate_normal(centroid, [[cov[0][0], cov[0][315]],[cov[1][0], cov[1][315]]]))
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: covariance is not positive-semidefinite.
#   after removing the cwd from sys.path.

# %%
out
# Out:
# [array([ 30.31821957, -97.74521087]),
#  array([ 30.36978522, -97.73521075]),
#  array([ 30.31864194, -97.74512896]),
#  array([ 30.38416233, -97.7324226 ]),
#  array([ 30.38177545, -97.73288548]),
#  array([ 30.25664238, -97.75715253]),
#  array([ 30.34278702, -97.74044651]),
#  array([ 30.43432176, -97.72269518]),
#  array([ 30.35548987, -97.73798304]),
#  array([ 30.15752488, -97.77637438]),
#  array([ 30.33858027, -97.74126232]),
#  array([ 30.36360967, -97.73640837]),
#  array([ 30.31497864, -97.74583938]),
#  array([ 30.19919656, -97.76829299]),
#  array([ 30.34493875, -97.74002922]),
#  array([ 30.20039335, -97.7680609 ]),
#  array([ 30.34251494, -97.74049927]),
#  array([ 30.15948338, -97.77599457]),
#  array([ 30.33673218, -97.74162072]),
#  array([ 30.32708523, -97.74349155]),
